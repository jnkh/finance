# %%
Pkg.update()

Pkg.add("Requests")
Pkg.add("ZipFile")

# %%
using ZipFile, Requests, DataFrames
# Out:
# INFO: Recompiling stale cache file /home/julian/.julia/lib/v0.4/DataFrames.ji for module DataFrames.
# INFO: Recompiling stale cache file /home/julian/.julia/lib/v0.4/DataArrays.ji for module DataArrays.
# INFO: Recompiling stale cache file /home/julian/.julia/lib/v0.4/SortingAlgorithms.ji for module SortingAlgorithms.
# INFO: Recompiling stale cache file /home/julian/.julia/lib/v0.4/Docile.ji for module Docile.

# %%
year = 2014
month = 12
month_str = "/12%20December"

destination_folder = "../data"
year_str = "/" * string(year)

dest = destination_folder * year_str * "/" * string(month)


curr1 = "EUR"
curr2 = "USD"
week = 1

filename = curr1 * "_" * curr2 * "_" * "Week$week"

zipped_ending = ".zip"
csv_ending = ".csv"


src_url = "ratedata.gaincapital.com"
# Out:
# "ratedata.gaincapital.com"

# %%
zipped = get("http://" * src_url * year_str * month_str * "/" * filename *zipped_ending)
save(zipped,dest * "/" * filename * zipped_ending)
run(`unzip $(dest * "/" * filename * zipped_ending) -d $dest`)
# Out:
# Archive:  ../data/2014/12/EUR_USD_Week1.zip
#   inflating: ../data/2014/12/EUR_USD_Week1.csv

# %%
df = readtable(dest * "/" * filename * csv_ending)
# Out:
# 339044x6 DataFrames.DataFrame
# | Row    | lTid       | cDealable | CurrencyPair |
# |--------|------------|-----------|--------------|
# | 1      | 3646611574 | "D"       | "EUR/USD"    |
# | 2      | 3646611593 | "D"       | "EUR/USD"    |
# | 3      | 3646611648 | "D"       | "EUR/USD"    |
# | 4      | 3646611664 | "D"       | "EUR/USD"    |
# | 5      | 3646611675 | "D"       | "EUR/USD"    |
# | 6      | 3646611703 | "D"       | "EUR/USD"    |
# | 7      | 3646611722 | "D"       | "EUR/USD"    |
# | 8      | 3646611738 | "D"       | "EUR/USD"    |
# | 9      | 3646611753 | "D"       | "EUR/USD"    |
# | 10     | 3646611770 | "D"       | "EUR/USD"    |
# | 11     | 3646611789 | "D"       | "EUR/USD"    |
# ⋮
# | 339033 | 3662643836 | "D"       | "EUR/USD"    |
# | 339034 | 3662643864 | "D"       | "EUR/USD"    |
# | 339035 | 3662643893 | "D"       | "EUR/USD"    |
# | 339036 | 3662643905 | "D"       | "EUR/USD"    |
# | 339037 | 3662643913 | "D"       | "EUR/USD"    |
# | 339038 | 3662643918 | "D"       | "EUR/USD"    |
# | 339039 | 3662643925 | "D"       | "EUR/USD"    |
# | 339040 | 3662643949 | "D"       | "EUR/USD"    |
# | 339041 | 3662643959 | "D"       | "EUR/USD"    |
# | 339042 | 3662643982 | "D"       | "EUR/USD"    |
# | 339043 | 3662643984 | "D"       | "EUR/USD"    |
# | 339044 | 3662643994 | "D"       | "EUR/USD"    |
#
# | Row    | RateDateTime                    | RateBid | RateAsk |
#  [1.24634,1.24633,1.24633,1.24633,1.24633,1.24633,1.24633,1.24633,1.24634,1.24636  …  1.22837,1.22836,1.22834,1.22833,1.22831,1.22835,1.22816,1.22818,1.22809,1.2281]
#  [1.24664,1.24664,1.2466,1.24661,1.2467,1.24664,1.2466,1.24668,1.24678,1.24678  …  1.22887,1.22886,1.22884,1.22883,1.22881,1.22885,1.22866,1.22868,1.22859,1.2285]

# %%
function as_date_time(s::AbstractString)
    DateTime(s,"yyyy-mm-dd HH:MM:SS.sssssssss")
end

@vectorize_1arg AbstractString as_date_time

function convert_to_logspace(vec)
    ret_vec = similar(vec)
    ret_vec[1] = 0.0
    for i = 1:length(vec)-1
        ret_vec[i+1] = log(vec[i+1]/vec[i])
    end
    ret_vec
end
# Out:
# as_date_time (generic function with 4 methods)

# %%
df[:,4] = as_date_time(df[:,4])
# Out:
# 339044-element Array{Any,1}:
#  2014-11-30T17:00:02.433
#  2014-11-30T17:00:02.933
#  2014-11-30T17:00:03.933
#  2014-11-30T17:00:04.183
#  2014-11-30T17:00:04.433
#  2014-11-30T17:00:05.433
#  2014-11-30T17:00:06.433
#  2014-11-30T17:00:07.183
#  2014-11-30T17:00:07.433
#  2014-11-30T17:00:07.683
#  2014-11-30T17:00:08.683
#  2014-11-30T17:00:09.683
#  2014-11-30T17:00:10.683
#  ⋮
#  2014-12-05T16:59:45.047
#  2014-12-05T16:59:45.797
#  2014-12-05T16:59:46.797
#  2014-12-05T16:59:48.297
#  2014-12-05T16:59:48.547
#  2014-12-05T16:59:49.547
#  2014-12-05T16:59:51.297
#  2014-12-05T16:59:55.047
#  2014-12-05T16:59:56.047
#  2014-12-05T16:59:57.547
#  2014-12-05T16:59:58.047
#  2014-12-05T16:59:59.047

# %%
len = 10000
plot(df[1:len,4],convert_to_logspace(df[1:len,6]))
plot(df[1:len,4],convert_to_logspace(df[1:len,5]))
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0x8cdf750>)
# 1-element Array{Any,1}:
#  PyObject <matplotlib.lines.Line2D object at 0x95b8710>

# %%
PyPlot.plt[:hist](convert_to_logspace(df[1:end,5]),bins=200,normed=false,log=true,alpha=0.4)
PyPlot.plt[:hist](convert_to_logspace(df[1:end,6]),bins=200,normed=false,log=true,alpha=0.4)

axvline(mean(convert_to_logspace(df[1:end,5])),color="r")
ylim([0.1,1e4])
xlim([-0.001,+0.001])
xlabel("Log change")
ylabel("Frequency")
# Out:
# PyPlot.Figure(PyObject <matplotlib.figure.Figure object at 0xaf61210>)
# PyObject <matplotlib.text.Text object at 0xcfe7850>

# %%
using PyPlot

# %%
function convert_to_logspace(vec)
    ret_vec = similar(vec)
    ret_vec[1] = 0.0
    for i = 1:length(vec)-1
        ret_vec[i+1] = log(vec[i+1]/vec[i])
    end
    ret_vec
end
# Out:
# convert_to_logspace (generic function with 1 method)
